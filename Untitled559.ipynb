# %%
import os
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_squared_error

# =====================================================
# 1️⃣ PATH
# =====================================================

base_path = r"C:\Users\NXTWAVE\Downloads\Strategic Disinvestment Revenue Prediction"
file_path = os.path.join(base_path, "fetchOGDReceiptStrategicSale.json")

# =====================================================
# 2️⃣ LOAD DATA
# =====================================================

with open(file_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

df = pd.DataFrame(data)

# =====================================================
# 3️⃣ CLEAN DATA
# =====================================================

df['amountRealised'] = df['amountRealised'].astype(str)
df['amountRealised'] = df['amountRealised'].str.replace(",", "")
df['amountRealised'] = df['amountRealised'].str.replace("*", "")
df['amountRealised'] = pd.to_numeric(df['amountRealised'], errors='coerce')

df['equitySold'] = pd.to_numeric(df['equitySold'], errors='coerce')
df['year_clean'] = df['year'].str.extract(r'(\d{4})')
df['year_clean'] = pd.to_numeric(df['year_clean'], errors='coerce')

df = df.dropna(subset=['amountRealised','equitySold','year_clean'])

print("\n📊 Cleaned Dataset Shape:", df.shape)

# =====================================================
# 4️⃣ HEATMAP
# =====================================================

plt.figure(figsize=(6,5))
sns.heatmap(df[['year_clean','equitySold','amountRealised']].corr(),
            annot=True, cmap='coolwarm')
plt.title("SAPLOA Heatmap")
plt.savefig(os.path.join(base_path,"saploa_heatmap.png"))
plt.show()

# =====================================================
# 5️⃣ FEATURES
# =====================================================

X = df[['year_clean','equitySold']]
y = df['amountRealised']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# =====================================================
# 6️⃣ PSO (Global Search)
# =====================================================

def pso_optimize(X_train,y_train,particles=20):
    best_score = -999
    best_params = None
    
    for _ in range(particles):
        n_estimators = random.randint(100,400)
        max_depth = random.randint(3,25)
        
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth
        )
        model.fit(X_train,y_train)
        pred = model.predict(X_train)
        score = r2_score(y_train,pred)
        
        if score > best_score:
            best_score = score
            best_params = (n_estimators,max_depth)
    
    return best_params

best_n, best_depth = pso_optimize(X_train,y_train)

print("\n🔹 PSO Best Params:", best_n, best_depth)

# =====================================================
# 7️⃣ ALOA (Local Refinement around PSO Best)
# =====================================================

def aloa_refine(X_train,y_train,base_n,base_depth,iterations=15):
    best_score = -999
    best_params = (base_n, base_depth)
    
    for _ in range(iterations):
        n_estimators = base_n + random.randint(-30,30)
        max_depth = base_depth + random.randint(-5,5)
        
        n_estimators = max(50, n_estimators)
        max_depth = max(2, max_depth)
        
        model = RandomForestRegressor(
            n_estimators=n_estimators,
            max_depth=max_depth
        )
        model.fit(X_train,y_train)
        pred = model.predict(X_train)
        score = r2_score(y_train,pred)
        
        if score > best_score:
            best_score = score
            best_params = (n_estimators,max_depth)
    
    return best_params

final_n, final_depth = aloa_refine(X_train,y_train,best_n,best_depth)

print("🔹 ALOA Refined Params:", final_n, final_depth)

# =====================================================
# 8️⃣ FINAL MODEL
# =====================================================

saploa_model = RandomForestRegressor(
    n_estimators=final_n,
    max_depth=final_depth
)

saploa_model.fit(X_train,y_train)

y_pred = saploa_model.predict(X_test)

saploa_r2 = r2_score(y_test,y_pred)
saploa_rmse = np.sqrt(mean_squared_error(y_test,y_pred))

print("\n🔥 SAPLOA RESULTS")
print("Final n_estimators:", final_n)
print("Final max_depth:", final_depth)
print("R2 Score:", saploa_r2)
print("RMSE:", saploa_rmse)

# =====================================================
# 9️⃣ SAVE MODEL
# =====================================================

joblib.dump(saploa_model,
            os.path.join(base_path,"saploa_model.pkl"))

# =====================================================
# 🔟 ACCURACY GRAPH
# =====================================================

plt.figure(figsize=(6,5))
plt.bar(["SAPLOA Hybrid"],[saploa_r2])
plt.title("SAPLOA Model Accuracy (R2)")
plt.ylabel("R2 Score")
plt.savefig(os.path.join(base_path,"saploa_accuracy_graph.png"))
plt.show()

# =====================================================
# 11️⃣ RMSE GRAPH
# =====================================================

plt.figure(figsize=(6,5))
plt.bar(["SAPLOA Hybrid"],[saploa_rmse])
plt.title("SAPLOA Model RMSE")
plt.ylabel("RMSE")
plt.savefig(os.path.join(base_path,"saploa_rmse_graph.png"))
plt.show()

# =====================================================
# 12️⃣ SAVE RESULT CSV
# =====================================================

results = pd.DataFrame({
    "Model":["SAPLOA (PSO+ALOA)"],
    "R2":[saploa_r2],
    "RMSE":[saploa_rmse],
    "Final_n_estimators":[final_n],
    "Final_max_depth":[final_depth]
})

results_path = os.path.join(base_path,"saploa_results.csv")
results.to_csv(results_path,index=False)

print("\n📁 Results saved at:", results_path)
print(results)

# =====================================================
# 13️⃣ SAVE PREDICTION CSV
# =====================================================

pred_df = pd.DataFrame({
    "Actual":y_test.values,
    "SAPLOA_Predicted":y_pred
})

pred_path = os.path.join(base_path,"saploa_prediction.csv")
pred_df.to_csv(pred_path,index=False)

print("\n📁 Prediction saved at:", pred_path)
print(pred_df.head())

# =====================================================
# 14️⃣ PREDICTION GRAPH
# =====================================================

plt.figure(figsize=(7,6))
plt.scatter(y_test,y_pred)
plt.xlabel("Actual Revenue")
plt.ylabel("SAPLOA Predicted Revenue")
plt.title("SAPLOA Hybrid Prediction")
plt.savefig(os.path.join(base_path,"saploa_prediction_graph.png"))
plt.show()

print("\n✅ SAPLOA HYBRID MODEL COMPLETED & SAVED SUCCESSFULLY!")
# Out:
# 📊 Cleaned Dataset Shape: (43, 10)
# 🔹 PSO Best Params: 228 18
# 🔹 ALOA Refined Params: 203 21
#
# 🔥 SAPLOA RESULTS
# Final n_estimators: 203
# Final max_depth: 21
# R2 Score: 0.021419873889679253
# RMSE: 11415.108228734069
# 📁 Results saved at: C:\Users\NXTWAVE\Downloads\Strategic Disinvestment Revenue Prediction\saploa_results.csv
#                Model       R2          RMSE  Final_n_estimators  \
# 0  SAPLOA (PSO+ALOA)  0.02142  11415.108229                 203
#
#    Final_max_depth
# 0               21
#
# 📁 Prediction saved at: C:\Users\NXTWAVE\Downloads\Strategic Disinvestment Revenue Prediction\saploa_prediction.csv
#      Actual  SAPLOA_Predicted
# 0   1049.17       8485.306386
# 1      8.38         30.416142
# 2     29.28         30.416142
# 3    285.00       7466.923143
# 4  36915.00       5349.571373
# ✅ SAPLOA HYBRID MODEL COMPLETED & SAVED SUCCESSFULLY!
